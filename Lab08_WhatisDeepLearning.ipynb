# %% [markdown]
# <a href="https://colab.research.google.com/github/WONYOUNG-SONG/DeepLearningTensorFlow2/blob/main/Lab08_DeepLearningBasic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab08: What is deep learning?**

# %% [markdown]
# **It's getting interesting, right?**
#
# **Finally we get to learn about deep learning!**

# %% [markdown]
# **What is deep learning?**
#
#
#
# > **Deep learning is a subset of Machine learning that uses multilayered neural networks**
#
# reference: https://www.ibm.com/topics/deep-learning

# %% [markdown]
# **The structure of a neural network is inspired by the structure of a neuron in the human brain.**

# %% [markdown]
# <div>
#   <img src="data:image/png;base64,..." width=500>
# </div>

# %% [markdown]
# **When this concept was first introduced to the world, scientists were trying to figure out a solution to the AND/OR problem.**

# %% [markdown]
# <div>
#   <img src="data:image/png;base64,..." width=300>
# </div>

# %% [markdown]
# **This can be separated linearly**

# %% [markdown]
# **How about XOR problem?**
#
# <div>
#   <img src="data:image/png;base64,..." width=150>
# </div>

# %% [markdown]
# **XOR cannot be solved with simple linear.**

# %% [markdown]
# **After years of not finding a way to solve this simple XOR problem, they finally got a solution.**

# %% [markdown]
# <div>
#   <img src="data:image/png;base64,..." width=500>
# </div>

# %% [markdown]
# **But Backpropagation soon ran into a big problem.**
#
# * Backpropagation just didn't work well for normal neural nets with many layers
# * Other rising machine learning algorithms: SVM, RandomForest, etc.

# %% [markdown]
# In early 2000, scientist founds that:
#
# * Neural networks with many layers really could be trained well if the weights are initialized in a clear way rather than randomly
# * Deep machine learning methods are more efficient for difficult problems than shallow methods.
