# %% [markdown]
# <a href="https://colab.research.google.com/github/WONYOUNG-SONG/DeepLearningTensorFlow2/blob/main/Lab05_LogisticRegressionClassfier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Lab05: Logistic Regression Classifier**
#
# https://github.com/WONYOUNG-SONG/DeepLearningZeroToAll/blob/master/tf2/tf2-05-1-logistic_regression.py

# %% [markdown]
# **Binary Classification**
#
# : classifying the elements of a set into one of two groups
#
# *ex) Spam detection: spam or not, Facebook feed: show or hide, Credit Card Fraudulent Transaction detection: legitimate or fraud*

# %% [markdown]
# **Classification has a value of only 0 or 1.**
#
# **Let's say 1 is pass and 0 is fail.**

# %% [markdown]
# <div>
#   <img src="data:image/png;base64,..." width=360>
# </div>

# %% [markdown]
# **In this case, we can use linear regression like this.**
#
# **And we can say if x < 5, it fails, and if x > 5, it passes.**

# %% [markdown]
# <div>
#   <img src="data:image/png;base64,..." width=360>
# </div>

# %% [markdown]
# **However, what if there is a really big number of x that is far away from the data set?**
#
# **Errors are inevitable because 0s are closer to the line than 1s.**

# %% [markdown]
# <div>
#   <img src="data:image/png;base64,..." width=370>
# </div>

# %% [markdown]
# **For this reason, H(x) = Wx + b is not suitable for classification.**
#
# **Then what should we use for classification?**
#
# hm.....
#
# **Well, there are some special functions for this case.**

# %% [markdown]
# **Sigmoid (logistic) function**: all values in this function are between 0 and 1.
#
# $$
# g(x) = \frac{1}{1+e^{-z}}
# $$

# %% [markdown]
# <div>
#   <img src="data:image/png;base64,..." width=400>
# </div>

# %% [markdown]
# So,
# $$
# H(x) = g(z)
# $$
# $$
# H(x) = \frac{1}{1+e^{-W^TX}}
# $$

# %% [markdown]
# # **Cost Function**

# %% [markdown]
# We can not use cost function of linear regression for Sigmoid function because sigmoid function has local minimums unlike linear regression.
#
# So, depending on our starting point, our results may vary.

# %% [markdown]
# **New cost function for logistic**
#
# $$
# cost(W)=\frac{1}{m}\sum(c(H(x),y)
# $$
#
# $$
# c(H(x),y) = \{^{-log(H(x)): y=1}_{-log(1-H(x)): y=0}
# $$

# %% [markdown]
# <div>
#   <img src="data:image/png;base64,..." width=500>
# </div>

# %% [markdown]
# When y = 1, cost approaches 0 (-log(x))
#
#
# When y = 0, cost approaches 0 (-log(1-x))

# %% [markdown]
# **We can write the equation in one line.**
#
# $$
# c(H(x), y) = -ylog(H(x))-(1-y)log(1-H(x))
# $$

# %% [markdown]
# # **Minimize cost - Gradient Decent Algorithm**

# %% [markdown]
# $$
# cost(W) = -\frac{1}{m}\sum ylog(H(x))+(1-y)log(1-H(x))
# $$
# $$
# W := W-\alpha \frac{d}{dW}cost(W)
# $$

# %% [markdown]
# # **Code and Explanation**

# %%
# Lab 5 Logistic Regression Classifier
import tensorflow as tf

x_data = [[1, 2],
          [2, 3],
          [3, 1],
          [4, 3],
          [5, 3],
          [6, 2]]
y_data = [[0],
          [0],
          [0],
          [1],
          [1],
          [1]]

tf.model = tf.keras.Sequential()
tf.model.add(tf.keras.layers.Dense(units=1, input_dim=2))
# use sigmoid activation for 0~1 problem
tf.model.add(tf.keras.layers.Activation('sigmoid'))

'''
better result with loss function == 'binary_crossentropy', try 'mse' for yourself
adding accuracy metric to get accuracy report during training
'''
tf.model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.SGD(lr=0.01), metrics=['accuracy'])
tf.model.summary()

history = tf.model.fit(x_data, y_data, epochs=5000)

# Accuracy report
print("Accuracy: ", history.history['accuracy'][-1])
